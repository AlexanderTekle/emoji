# %%
import torch
import torch.nn as nn
import torchvision.models as models

class HandGestureModel(nn.Module):
    def __init__(self, num_classes):
        super(HandGestureModel, self).__init__()
        self.resnet = models.resnet18(pretrained=True)
        num_features = self.resnet.fc.in_features
        self.resnet.fc = nn.Identity()
        self.fc1 = nn.Linear(num_features, 128)
        self.fc2 = nn.Linear(128, num_classes)
        self.fc3 = nn.Linear(128, 4)  # for bounding box regression

    def forward(self, x):
        features = self.resnet(x)
        features = torch.relu_(self.fc1(features))
        class_output = self.fc2(features)
        bbox_output = self.fc3(features)
        return class_output, bbox_output

# %%
import nobuco
from nobuco import ChannelOrder, ChannelOrderingStrategy
from nobuco.layers.weight import WeightLayer

# %%
model = HandGestureModel(5)
model.load_state_dict(torch.load("/Users/alexandertekle/Documents/Code/Handmoji/hand_gesture_model_290.pth"))
model.eval()
# Out:
# HandGestureModel(
#   (resnet): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Identity()
#   )
#   (fc1): Linear(in_features=512, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=5, bias=True)
#   (fc3): Linear(in_features=128, out_features=4, bias=True)
# )

# %%
# Define input shape
dummy_image = torch.randn(1, 3, 224, 224)  # Adjust based on your model's input

# # Convert PyTorch to Keras
# keras_model = pytorch2keras(model, input_shape, verbose=True)

# # Save as TensorFlow.js model
# tfjs.converters.save_keras_model(keras_model, "path/to/tfjs_model")

# %%
keras_model = nobuco.pytorch_to_keras(
    model,
    args=[dummy_image],
    outputs_channel_order=ChannelOrder.TENSORFLOW
)
# Out:
# Legend:
#     Green — conversion successful
#     Yellow — conversion imprecise
#     Red — conversion failed
#     Red — no converter found
#     Bold — conversion applied directly
#     * — subgraph reused
#     Tensor — this output is not dependent on any of subgraph's input tensors
#     Tensor — this input is a parameter / constant
#     Tensor — this tensor is useless
#
# HandGestureModel[__main__](float32_0<1,3,224,224>) -> (float32_149<1,5>, float32_152<1,4>)
#  │  ResNet[torchvision.models.resnet](float32_0<1,3,224,224>) -> float32_143<1,512>
#  │   │  Conv2d[torch.nn.modules.conv](float32_0<1,3,224,224>) -> float32_2<1,64,112,112>
#  │   │   └· conv2d[torch.nn.functional](float32_0<1,3,224,224>, float32_1<64,3,7,7>, None, (2, 2), (3, 3), (1, 1), 1) -> float32_2<1,64,112,112>
#  │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_2<1,64,112,112>) -> float32_7<1,64,112,112>
#  │   │   ├· batch_norm[torch.nn.functional](float32_2<1,64,112,112>, float32_3<64>, float32_4<64>, float32_5<64>, float32_6<64>, False, 0.1, 1e-05) -> float32_7<1,64,112,112>
#  │   │   └   └· batch_norm[torch](float32_2<1,64,112,112>, float32_5<64>, float32_6<64>, float32_3<64>, float32_4<64>, False, 0.1, 1e-05, True) -> float32_7<1,64,112,112>
#  │   │   (!) Inplace
#  │   │  ReLU[torch.nn.modules.activation](float32_7<1,64,112,112>) -> float32_7<1,64,112,112>
#  │   │   ├· relu[torch.nn.functional](float32_7<1,64,112,112>, inplace=True) -> float32_7<1,64,112,112>
#  │   │   └   └· relu_[torch](float32_7<1,64,112,112>) -> float32_7<1,64,112,112>
#  │   │  MaxPool2d[torch.nn.modules.pooling](float32_7<1,64,112,112>) -> float32_8<1,64,56,56>
#  │   │   ├· max_pool2d[torch.nn.functional](float32_7<1,64,112,112>, 3, 2, 1, 1, ceil_mode=False, return_indices=False) -> float32_8<1,64,56,56>
#  │   │   └   └· max_pool2d[torch](float32_7<1,64,112,112>, 3, 2, 1, 1, False) -> float32_8<1,64,56,56>
#  │   │  Sequential[torch.nn.modules.container](float32_8<1,64,56,56>) -> float32_36<1,64,56,56>
#  │   │   │  BasicBlock[torchvision.models.resnet](float32_8<1,64,56,56>) -> float32_22<1,64,56,56>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_8<1,64,56,56>) -> float32_10<1,64,56,56>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_8<1,64,56,56>, float32_9<64,64,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_10<1,64,56,56>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_10<1,64,56,56>) -> float32_15<1,64,56,56>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_10<1,64,56,56>, float32_11<64>, float32_12<64>, float32_13<64>, float32_14<64>, False, 0.1, 1e-05) -> float32_15<1,64,56,56>
#  │   │   │   │   └   └· batch_norm[torch](float32_10<1,64,56,56>, float32_13<64>, float32_14<64>, float32_11<64>, float32_12<64>, False, 0.1, 1e-05, True) -> float32_15<1,64,56,56>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  ReLU[torch.nn.modules.activation](float32_15<1,64,56,56>) -> float32_15<1,64,56,56>
#  │   │   │   │   ├· relu[torch.nn.functional](float32_15<1,64,56,56>, inplace=True) -> float32_15<1,64,56,56>
#  │   │   │   │   └   └· relu_[torch](float32_15<1,64,56,56>) -> float32_15<1,64,56,56>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_15<1,64,56,56>) -> float32_17<1,64,56,56>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_15<1,64,56,56>, float32_16<64,64,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_17<1,64,56,56>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_17<1,64,56,56>) -> float32_22<1,64,56,56>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_17<1,64,56,56>, float32_18<64>, float32_19<64>, float32_20<64>, float32_21<64>, False, 0.1, 1e-05) -> float32_22<1,64,56,56>
#  │   │   │   │   └   └· batch_norm[torch](float32_17<1,64,56,56>, float32_20<64>, float32_21<64>, float32_18<64>, float32_19<64>, False, 0.1, 1e-05, True) -> float32_22<1,64,56,56>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  __iadd__[torch.Tensor](float32_22<1,64,56,56>, float32_8<1,64,56,56>) -> float32_22<1,64,56,56>
#  │   │   │   │   └· add_[TensorBase](float32_22<1,64,56,56>, float32_8<1,64,56,56>) -> float32_22<1,64,56,56>
#  │   │   │   │   (!) Inplace
#  │   │   │   └· *ReLU[torch.nn.modules.activation](float32_22<1,64,56,56>) -> float32_22<1,64,56,56>
#  │   │   ├· BasicBlock[torchvision.models.resnet](float32_22<1,64,56,56>) -> float32_36<1,64,56,56>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_22<1,64,56,56>) -> float32_24<1,64,56,56>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_22<1,64,56,56>, float32_23<64,64,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_24<1,64,56,56>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_24<1,64,56,56>) -> float32_29<1,64,56,56>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_24<1,64,56,56>, float32_25<64>, float32_26<64>, float32_27<64>, float32_28<64>, False, 0.1, 1e-05) -> float32_29<1,64,56,56>
#  │   │   │   │   └   └· batch_norm[torch](float32_24<1,64,56,56>, float32_27<64>, float32_28<64>, float32_25<64>, float32_26<64>, False, 0.1, 1e-05, True) -> float32_29<1,64,56,56>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  ReLU[torch.nn.modules.activation](float32_29<1,64,56,56>) -> float32_29<1,64,56,56>
#  │   │   │   │   ├· relu[torch.nn.functional](float32_29<1,64,56,56>, inplace=True) -> float32_29<1,64,56,56>
#  │   │   │   │   └   └· relu_[torch](float32_29<1,64,56,56>) -> float32_29<1,64,56,56>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_29<1,64,56,56>) -> float32_31<1,64,56,56>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_29<1,64,56,56>, float32_30<64,64,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_31<1,64,56,56>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_31<1,64,56,56>) -> float32_36<1,64,56,56>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_31<1,64,56,56>, float32_32<64>, float32_33<64>, float32_34<64>, float32_35<64>, False, 0.1, 1e-05) -> float32_36<1,64,56,56>
#  │   │   │   │   └   └· batch_norm[torch](float32_31<1,64,56,56>, float32_34<64>, float32_35<64>, float32_32<64>, float32_33<64>, False, 0.1, 1e-05, True) -> float32_36<1,64,56,56>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  __iadd__[torch.Tensor](float32_36<1,64,56,56>, float32_22<1,64,56,56>) -> float32_36<1,64,56,56>
#  │   │   │   │   └· add_[TensorBase](float32_36<1,64,56,56>, float32_22<1,64,56,56>) -> float32_36<1,64,56,56>
#  │   │   │   │   (!) Inplace
#  │   │   └   └· *ReLU[torch.nn.modules.activation](float32_36<1,64,56,56>) -> float32_36<1,64,56,56>
#  │   │  Sequential[torch.nn.modules.container](float32_36<1,64,56,56>) -> float32_71<1,128,28,28>
#  │   │   │  BasicBlock[torchvision.models.resnet](float32_36<1,64,56,56>) -> float32_50<1,128,28,28>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_36<1,64,56,56>) -> float32_38<1,128,28,28>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_36<1,64,56,56>, float32_37<128,64,3,3>, None, (2, 2), (1, 1), (1, 1), 1) -> float32_38<1,128,28,28>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_38<1,128,28,28>) -> float32_43<1,128,28,28>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_38<1,128,28,28>, float32_39<128>, float32_40<128>, float32_41<128>, float32_42<128>, False, 0.1, 1e-05) -> float32_43<1,128,28,28>
#  │   │   │   │   └   └· batch_norm[torch](float32_38<1,128,28,28>, float32_41<128>, float32_42<128>, float32_39<128>, float32_40<128>, False, 0.1, 1e-05, True) -> float32_43<1,128,28,28>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  ReLU[torch.nn.modules.activation](float32_43<1,128,28,28>) -> float32_43<1,128,28,28>
#  │   │   │   │   ├· relu[torch.nn.functional](float32_43<1,128,28,28>, inplace=True) -> float32_43<1,128,28,28>
#  │   │   │   │   └   └· relu_[torch](float32_43<1,128,28,28>) -> float32_43<1,128,28,28>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_43<1,128,28,28>) -> float32_45<1,128,28,28>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_43<1,128,28,28>, float32_44<128,128,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_45<1,128,28,28>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_45<1,128,28,28>) -> float32_50<1,128,28,28>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_45<1,128,28,28>, float32_46<128>, float32_47<128>, float32_48<128>, float32_49<128>, False, 0.1, 1e-05) -> float32_50<1,128,28,28>
#  │   │   │   │   └   └· batch_norm[torch](float32_45<1,128,28,28>, float32_48<128>, float32_49<128>, float32_46<128>, float32_47<128>, False, 0.1, 1e-05, True) -> float32_50<1,128,28,28>
#  │   │   │   │  Sequential[torch.nn.modules.container](float32_36<1,64,56,56>) -> float32_57<1,128,28,28>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_36<1,64,56,56>) -> float32_52<1,128,28,28>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_36<1,64,56,56>, float32_51<128,64,1,1>, None, (2, 2), (0, 0), (1, 1), 1) -> float32_52<1,128,28,28>
#  │   │   │   │   ├· BatchNorm2d[torch.nn.modules.batchnorm](float32_52<1,128,28,28>) -> float32_57<1,128,28,28>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_52<1,128,28,28>, float32_53<128>, float32_54<128>, float32_55<128>, float32_56<128>, False, 0.1, 1e-05) -> float32_57<1,128,28,28>
#  │   │   │   │   └   └   └· batch_norm[torch](float32_52<1,128,28,28>, float32_55<128>, float32_56<128>, float32_53<128>, float32_54<128>, False, 0.1, 1e-05, True) -> float32_57<1,128,28,28>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  __iadd__[torch.Tensor](float32_50<1,128,28,28>, float32_57<1,128,28,28>) -> float32_50<1,128,28,28>
#  │   │   │   │   └· add_[TensorBase](float32_50<1,128,28,28>, float32_57<1,128,28,28>) -> float32_50<1,128,28,28>
#  │   │   │   │   (!) Inplace
#  │   │   │   └· *ReLU[torch.nn.modules.activation](float32_50<1,128,28,28>) -> float32_50<1,128,28,28>
#  │   │   ├· BasicBlock[torchvision.models.resnet](float32_50<1,128,28,28>) -> float32_71<1,128,28,28>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_50<1,128,28,28>) -> float32_59<1,128,28,28>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_50<1,128,28,28>, float32_58<128,128,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_59<1,128,28,28>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_59<1,128,28,28>) -> float32_64<1,128,28,28>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_59<1,128,28,28>, float32_60<128>, float32_61<128>, float32_62<128>, float32_63<128>, False, 0.1, 1e-05) -> float32_64<1,128,28,28>
#  │   │   │   │   └   └· batch_norm[torch](float32_59<1,128,28,28>, float32_62<128>, float32_63<128>, float32_60<128>, float32_61<128>, False, 0.1, 1e-05, True) -> float32_64<1,128,28,28>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  ReLU[torch.nn.modules.activation](float32_64<1,128,28,28>) -> float32_64<1,128,28,28>
#  │   │   │   │   ├· relu[torch.nn.functional](float32_64<1,128,28,28>, inplace=True) -> float32_64<1,128,28,28>
#  │   │   │   │   └   └· relu_[torch](float32_64<1,128,28,28>) -> float32_64<1,128,28,28>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_64<1,128,28,28>) -> float32_66<1,128,28,28>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_64<1,128,28,28>, float32_65<128,128,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_66<1,128,28,28>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_66<1,128,28,28>) -> float32_71<1,128,28,28>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_66<1,128,28,28>, float32_67<128>, float32_68<128>, float32_69<128>, float32_70<128>, False, 0.1, 1e-05) -> float32_71<1,128,28,28>
#  │   │   │   │   └   └· batch_norm[torch](float32_66<1,128,28,28>, float32_69<128>, float32_70<128>, float32_67<128>, float32_68<128>, False, 0.1, 1e-05, True) -> float32_71<1,128,28,28>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  __iadd__[torch.Tensor](float32_71<1,128,28,28>, float32_50<1,128,28,28>) -> float32_71<1,128,28,28>
#  │   │   │   │   └· add_[TensorBase](float32_71<1,128,28,28>, float32_50<1,128,28,28>) -> float32_71<1,128,28,28>
#  │   │   │   │   (!) Inplace
#  │   │   └   └· *ReLU[torch.nn.modules.activation](float32_71<1,128,28,28>) -> float32_71<1,128,28,28>
#  │   │  Sequential[torch.nn.modules.container](float32_71<1,128,28,28>) -> float32_106<1,256,14,14>
#  │   │   │  BasicBlock[torchvision.models.resnet](float32_71<1,128,28,28>) -> float32_85<1,256,14,14>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_71<1,128,28,28>) -> float32_73<1,256,14,14>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_71<1,128,28,28>, float32_72<256,128,3,3>, None, (2, 2), (1, 1), (1, 1), 1) -> float32_73<1,256,14,14>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_73<1,256,14,14>) -> float32_78<1,256,14,14>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_73<1,256,14,14>, float32_74<256>, float32_75<256>, float32_76<256>, float32_77<256>, False, 0.1, 1e-05) -> float32_78<1,256,14,14>
#  │   │   │   │   └   └· batch_norm[torch](float32_73<1,256,14,14>, float32_76<256>, float32_77<256>, float32_74<256>, float32_75<256>, False, 0.1, 1e-05, True) -> float32_78<1,256,14,14>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  ReLU[torch.nn.modules.activation](float32_78<1,256,14,14>) -> float32_78<1,256,14,14>
#  │   │   │   │   ├· relu[torch.nn.functional](float32_78<1,256,14,14>, inplace=True) -> float32_78<1,256,14,14>
#  │   │   │   │   └   └· relu_[torch](float32_78<1,256,14,14>) -> float32_78<1,256,14,14>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_78<1,256,14,14>) -> float32_80<1,256,14,14>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_78<1,256,14,14>, float32_79<256,256,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_80<1,256,14,14>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_80<1,256,14,14>) -> float32_85<1,256,14,14>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_80<1,256,14,14>, float32_81<256>, float32_82<256>, float32_83<256>, float32_84<256>, False, 0.1, 1e-05) -> float32_85<1,256,14,14>
#  │   │   │   │   └   └· batch_norm[torch](float32_80<1,256,14,14>, float32_83<256>, float32_84<256>, float32_81<256>, float32_82<256>, False, 0.1, 1e-05, True) -> float32_85<1,256,14,14>
#  │   │   │   │  Sequential[torch.nn.modules.container](float32_71<1,128,28,28>) -> float32_92<1,256,14,14>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_71<1,128,28,28>) -> float32_87<1,256,14,14>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_71<1,128,28,28>, float32_86<256,128,1,1>, None, (2, 2), (0, 0), (1, 1), 1) -> float32_87<1,256,14,14>
#  │   │   │   │   ├· BatchNorm2d[torch.nn.modules.batchnorm](float32_87<1,256,14,14>) -> float32_92<1,256,14,14>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_87<1,256,14,14>, float32_88<256>, float32_89<256>, float32_90<256>, float32_91<256>, False, 0.1, 1e-05) -> float32_92<1,256,14,14>
#  │   │   │   │   └   └   └· batch_norm[torch](float32_87<1,256,14,14>, float32_90<256>, float32_91<256>, float32_88<256>, float32_89<256>, False, 0.1, 1e-05, True) -> float32_92<1,256,14,14>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  __iadd__[torch.Tensor](float32_85<1,256,14,14>, float32_92<1,256,14,14>) -> float32_85<1,256,14,14>
#  │   │   │   │   └· add_[TensorBase](float32_85<1,256,14,14>, float32_92<1,256,14,14>) -> float32_85<1,256,14,14>
#  │   │   │   │   (!) Inplace
#  │   │   │   └· *ReLU[torch.nn.modules.activation](float32_85<1,256,14,14>) -> float32_85<1,256,14,14>
#  │   │   ├· BasicBlock[torchvision.models.resnet](float32_85<1,256,14,14>) -> float32_106<1,256,14,14>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_85<1,256,14,14>) -> float32_94<1,256,14,14>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_85<1,256,14,14>, float32_93<256,256,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_94<1,256,14,14>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_94<1,256,14,14>) -> float32_99<1,256,14,14>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_94<1,256,14,14>, float32_95<256>, float32_96<256>, float32_97<256>, float32_98<256>, False, 0.1, 1e-05) -> float32_99<1,256,14,14>
#  │   │   │   │   └   └· batch_norm[torch](float32_94<1,256,14,14>, float32_97<256>, float32_98<256>, float32_95<256>, float32_96<256>, False, 0.1, 1e-05, True) -> float32_99<1,256,14,14>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  ReLU[torch.nn.modules.activation](float32_99<1,256,14,14>) -> float32_99<1,256,14,14>
#  │   │   │   │   ├· relu[torch.nn.functional](float32_99<1,256,14,14>, inplace=True) -> float32_99<1,256,14,14>
#  │   │   │   │   └   └· relu_[torch](float32_99<1,256,14,14>) -> float32_99<1,256,14,14>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_99<1,256,14,14>) -> float32_101<1,256,14,14>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_99<1,256,14,14>, float32_100<256,256,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_101<1,256,14,14>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_101<1,256,14,14>) -> float32_106<1,256,14,14>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_101<1,256,14,14>, float32_102<256>, float32_103<256>, float32_104<256>, float32_105<256>, False, 0.1, 1e-05) -> float32_106<1,256,14,14>
#  │   │   │   │   └   └· batch_norm[torch](float32_101<1,256,14,14>, float32_104<256>, float32_105<256>, float32_102<256>, float32_103<256>, False, 0.1, 1e-05, True) -> float32_106<1,256,14,14>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  __iadd__[torch.Tensor](float32_106<1,256,14,14>, float32_85<1,256,14,14>) -> float32_106<1,256,14,14>
#  │   │   │   │   └· add_[TensorBase](float32_106<1,256,14,14>, float32_85<1,256,14,14>) -> float32_106<1,256,14,14>
#  │   │   │   │   (!) Inplace
#  │   │   └   └· *ReLU[torch.nn.modules.activation](float32_106<1,256,14,14>) -> float32_106<1,256,14,14>
#  │   │  Sequential[torch.nn.modules.container](float32_106<1,256,14,14>) -> float32_141<1,512,7,7>
#  │   │   │  BasicBlock[torchvision.models.resnet](float32_106<1,256,14,14>) -> float32_120<1,512,7,7>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_106<1,256,14,14>) -> float32_108<1,512,7,7>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_106<1,256,14,14>, float32_107<512,256,3,3>, None, (2, 2), (1, 1), (1, 1), 1) -> float32_108<1,512,7,7>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_108<1,512,7,7>) -> float32_113<1,512,7,7>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_108<1,512,7,7>, float32_109<512>, float32_110<512>, float32_111<512>, float32_112<512>, False, 0.1, 1e-05) -> float32_113<1,512,7,7>
#  │   │   │   │   └   └· batch_norm[torch](float32_108<1,512,7,7>, float32_111<512>, float32_112<512>, float32_109<512>, float32_110<512>, False, 0.1, 1e-05, True) -> float32_113<1,512,7,7>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  ReLU[torch.nn.modules.activation](float32_113<1,512,7,7>) -> float32_113<1,512,7,7>
#  │   │   │   │   ├· relu[torch.nn.functional](float32_113<1,512,7,7>, inplace=True) -> float32_113<1,512,7,7>
#  │   │   │   │   └   └· relu_[torch](float32_113<1,512,7,7>) -> float32_113<1,512,7,7>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_113<1,512,7,7>) -> float32_115<1,512,7,7>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_113<1,512,7,7>, float32_114<512,512,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_115<1,512,7,7>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_115<1,512,7,7>) -> float32_120<1,512,7,7>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_115<1,512,7,7>, float32_116<512>, float32_117<512>, float32_118<512>, float32_119<512>, False, 0.1, 1e-05) -> float32_120<1,512,7,7>
#  │   │   │   │   └   └· batch_norm[torch](float32_115<1,512,7,7>, float32_118<512>, float32_119<512>, float32_116<512>, float32_117<512>, False, 0.1, 1e-05, True) -> float32_120<1,512,7,7>
#  │   │   │   │  Sequential[torch.nn.modules.container](float32_106<1,256,14,14>) -> float32_127<1,512,7,7>
#  │   │   │   │   │  Conv2d[torch.nn.modules.conv](float32_106<1,256,14,14>) -> float32_122<1,512,7,7>
#  │   │   │   │   │   └· conv2d[torch.nn.functional](float32_106<1,256,14,14>, float32_121<512,256,1,1>, None, (2, 2), (0, 0), (1, 1), 1) -> float32_122<1,512,7,7>
#  │   │   │   │   ├· BatchNorm2d[torch.nn.modules.batchnorm](float32_122<1,512,7,7>) -> float32_127<1,512,7,7>
#  │   │   │   │   │   ├· batch_norm[torch.nn.functional](float32_122<1,512,7,7>, float32_123<512>, float32_124<512>, float32_125<512>, float32_126<512>, False, 0.1, 1e-05) -> float32_127<1,512,7,7>
#  │   │   │   │   └   └   └· batch_norm[torch](float32_122<1,512,7,7>, float32_125<512>, float32_126<512>, float32_123<512>, float32_124<512>, False, 0.1, 1e-05, True) -> float32_127<1,512,7,7>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  __iadd__[torch.Tensor](float32_120<1,512,7,7>, float32_127<1,512,7,7>) -> float32_120<1,512,7,7>
#  │   │   │   │   └· add_[TensorBase](float32_120<1,512,7,7>, float32_127<1,512,7,7>) -> float32_120<1,512,7,7>
#  │   │   │   │   (!) Inplace
#  │   │   │   └· *ReLU[torch.nn.modules.activation](float32_120<1,512,7,7>) -> float32_120<1,512,7,7>
#  │   │   ├· BasicBlock[torchvision.models.resnet](float32_120<1,512,7,7>) -> float32_141<1,512,7,7>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_120<1,512,7,7>) -> float32_129<1,512,7,7>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_120<1,512,7,7>, float32_128<512,512,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_129<1,512,7,7>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_129<1,512,7,7>) -> float32_134<1,512,7,7>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_129<1,512,7,7>, float32_130<512>, float32_131<512>, float32_132<512>, float32_133<512>, False, 0.1, 1e-05) -> float32_134<1,512,7,7>
#  │   │   │   │   └   └· batch_norm[torch](float32_129<1,512,7,7>, float32_132<512>, float32_133<512>, float32_130<512>, float32_131<512>, False, 0.1, 1e-05, True) -> float32_134<1,512,7,7>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  ReLU[torch.nn.modules.activation](float32_134<1,512,7,7>) -> float32_134<1,512,7,7>
#  │   │   │   │   ├· relu[torch.nn.functional](float32_134<1,512,7,7>, inplace=True) -> float32_134<1,512,7,7>
#  │   │   │   │   └   └· relu_[torch](float32_134<1,512,7,7>) -> float32_134<1,512,7,7>
#  │   │   │   │  Conv2d[torch.nn.modules.conv](float32_134<1,512,7,7>) -> float32_136<1,512,7,7>
#  │   │   │   │   └· conv2d[torch.nn.functional](float32_134<1,512,7,7>, float32_135<512,512,3,3>, None, (1, 1), (1, 1), (1, 1), 1) -> float32_136<1,512,7,7>
#  │   │   │   │  BatchNorm2d[torch.nn.modules.batchnorm](float32_136<1,512,7,7>) -> float32_141<1,512,7,7>
#  │   │   │   │   ├· batch_norm[torch.nn.functional](float32_136<1,512,7,7>, float32_137<512>, float32_138<512>, float32_139<512>, float32_140<512>, False, 0.1, 1e-05) -> float32_141<1,512,7,7>
#  │   │   │   │   └   └· batch_norm[torch](float32_136<1,512,7,7>, float32_139<512>, float32_140<512>, float32_137<512>, float32_138<512>, False, 0.1, 1e-05, True) -> float32_141<1,512,7,7>
#  │   │   │   │   (!) Inplace
#  │   │   │   │  __iadd__[torch.Tensor](float32_141<1,512,7,7>, float32_120<1,512,7,7>) -> float32_141<1,512,7,7>
#  │   │   │   │   └· add_[TensorBase](float32_141<1,512,7,7>, float32_120<1,512,7,7>) -> float32_141<1,512,7,7>
#  │   │   │   │   (!) Inplace
#  │   │   └   └· *ReLU[torch.nn.modules.activation](float32_141<1,512,7,7>) -> float32_141<1,512,7,7>
#  │   │  AdaptiveAvgPool2d[torch.nn.modules.pooling](float32_141<1,512,7,7>) -> float32_142<1,512,1,1>
#  │   │   └· adaptive_avg_pool2d[torch.nn.functional](float32_141<1,512,7,7>, (1, 1)) -> float32_142<1,512,1,1>
#  │   │  flatten[torch](float32_142<1,512,1,1>, 1) -> float32_143<1,512>
#  │   └· Identity[torch.nn.modules.linear](float32_143<1,512>) -> float32_143<1,512>
#  │  Linear[torch.nn.modules.linear](float32_143<1,512>) -> float32_146<1,128>
#  │   └· linear[torch.nn.functional](float32_143<1,512>, float32_144<128,512>, float32_145<128>) -> float32_146<1,128>
#  │   (!) Inplace
#  │  relu_[torch](float32_146<1,128>) -> float32_146<1,128>
#  ├· Linear[torch.nn.modules.linear](float32_146<1,128>) -> float32_149<1,5>
#  │   └· linear[torch.nn.functional](float32_146<1,128>, float32_147<5,128>, float32_148<5>) -> float32_149<1,5>
#  ├· Linear[torch.nn.modules.linear](float32_146<1,128>) -> float32_152<1,4>
#  └   └· linear[torch.nn.functional](float32_146<1,128>, float32_150<4,128>, float32_151<4>) -> float32_152<1,4>
#
# Conversion complete. Elapsed time: 0.64 sec.

# %%
type(keras_model)
# Out:
# keras.src.engine.functional.Functional

# %%
keras_model.save("/Users/alexandertekle/Documents/Code/Handmoji/models/model290", save_format="tf")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /Users/alexandertekle/Documents/Code/Handmoji/models/model290/assets
# INFO:tensorflow:Assets written to: /Users/alexandertekle/Documents/Code/Handmoji/models/model290/assets

# %%
from tensorflowjs import converters, quantization

# %%
converters.convert_tf_saved_model(saved_model_dir="/Users/alexandertekle/Documents/Code/Handmoji/models/model290", 
                                  output_dir="/Users/alexandertekle/Documents/Code/Handmoji/models/model290/tensorflow", 
                                  quantization_dtype_map={quantization.QUANTIZATION_DTYPE_UINT8:True})
